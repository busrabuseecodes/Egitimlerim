# %% [markdown]
# # Computational ThinkingKaynak: https://blockly.games/## Düşünce Modelleri- Decomposition- Pattern Recognition- Abstraction- Algorithm

# %% [markdown]
# ### Trafik Işıkları Senaryosu- Decomposition: Yeşil, sarı ve kırmızı ışık durumlarının belirlenmesi- Pattern Recognition: Hangi araçların hangi ışıkta geçtiğinin tespiti- Abstraction: Kırmızı ışıkta geçme durumlarının incelenmesi- Algorithm: Kırmızı ışıkta geçen araçların tespiti ve ceza kaydı oluşturulması

# %% [markdown]
# ### 1'den 100'e Toplam Problemi- Decomposition: 1+2+3…+100- Pattern Recognition: 1+100=101, 2+99=101, 3+98=101- Abstraction: 50 adet 101- Algorithm: 50 x 101

# %%
toplam = sum(range(1, 101))print('Toplam:', toplam)n = 100gauss = (n * (n + 1)) // 2print('Gauss yöntemiyle toplam:', gauss)

# %% [markdown]
# ## Top 10 Business Skills Employers are Looking for in 2025- AI Literacy (Yapay Zeka Okuryazarlığı)- Digital Transformation (Dijital Dönüşüm)- Lifelong Learning (Yaşam Boyu Öğrenme)- Emotional Intelligence (Duygusal Zekâ)- Analytical Thinking (Analitik Düşünme)- Creativity (Yaratıcılık)- Leadership and Social Influence (Liderlik ve Sosyal Etki)- Adaptability and Resilience (Uyumluluk ve Dayanıklılık)- Critical Thinking (Eleştirel Düşünme)- Complex Problem-Solving (Karmaşık Problem Çözme)

# %% [markdown]
# ### Ortalama Hesaplama Algoritması (Pseudocode)START → DECLARE sayi1, sayi2, ort → INPUT sayi1, sayi2 → SET ort = (sayi1+sayi2)/2 → PRINT ort → END

# %%
sayi1 = int(input('Birinci sayıyı gir: '))sayi2 = int(input('İkinci sayıyı gir: '))ort = (sayi1 + sayi2) / 2print('Ortalama:', ort)
