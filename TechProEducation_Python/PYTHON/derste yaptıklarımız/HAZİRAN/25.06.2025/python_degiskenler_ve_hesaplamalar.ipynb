# %% [markdown]
# # Değişken İsimlendirme ve Basit Hesaplamalar
#
# Bu notebook şu konuları içerir:
# - Geçerli / geçersiz değişken isimleri örnekleri
# - Yaş ile basit hesaplama
# - Dairenin alanı (pi kullanımı)
# - Pisagor ile hipotenüs hesaplama
# - Faydalı kaynak: Unicode emoji listesi

# %% [markdown]
# ## Değişken İsimlendirme Kuralları (Kısa)
#
# - Değişken adı harf veya `_` ile başlamalı; rakamla başlayamaz.
# - Boşluk, `-`, `.`, `$` gibi özel karakterler kullanılamaz.
# - Küçük/büyük harf ayrımı vardır.
# - Anlamlı ve tutarlı isimlendirme tercih edilir (örn. `first_name`).

# %%
# Düzeltilmiş ve geçerli değişken isimleri
name_1 = 'Melisa'
name_2 = 'Anna'
name_3 = 'Yasin'
first_name = 'George'
name_4 = 'Ceylan'
name_5 = 'Ali'
firstName = 'Cenk'   # camelCase örneği (geçerli)
name_6 = 'Selim'
first_name_2 = 'Belen'

# Yazdırma örneği
print(name_1, name_2, name_3)
print(first_name, name_4, name_5)
print(firstName, name_6, first_name_2)
# Out:
# Melisa Anna Yasin
# George Ceylan Ali
# Cenk Selim Belen

# %% [markdown]
# ## Yaş ile Basit Hesaplama
# Örnek: `age = "40"` verildiğinde 2025 yılına göre doğum yılını hesaplama.

# %%
age = "40"
birth_year_2025 = 2025 - int(age)
print(f"2025 yılına göre doğum yılı: {birth_year_2025}")

# Güncel yıla göre hesaplama (daha doğru)
from datetime import datetime
current_year = datetime.now().year
birth_year_now = current_year - int(age)
print(f"Güncel yıla göre doğum yılı: {birth_year_now}")
# Out:
# 2025 yılına göre doğum yılı: 1985
# Güncel yıla göre doğum yılı: 1986

# %% [markdown]
# ## Dairenin Alanı
# Formül: alan = π * r^2
# Örnek: r = 7. `pi` için `math.pi` kullanmak daha doğru sonuç verir.

# %%
import math

r = 7
pi = 3            # verilen örnekte pi=3 kullanılmıştı (yaklaşık)
alan_approx = pi * r**2
print("Yaklaşık alan (pi=3):", alan_approx)

# Gerçekçi hesaplama
alan_true = math.pi * r**2
print("Gerçek alan (math.pi):", alan_true)
# Out:
# Yaklaşık alan (pi=3): 147
# Gerçek alan (math.pi): 153.93804002589985

# %% [markdown]
# ## Pisagor ile Hipotenüs
# Formül: c = sqrt(a^2 + b^2)
# Örnek: a = 5, b = 12

# %%
import math

a = 5
b = 12
c = math.sqrt(a**2 + b**2)
print(f"Hipotenüs c = {c}")
# Alternatif (üs ile)
c_alt = (a**2 + b**2)**0.5
print(f"Hipotenüs (alternatif) c = {c_alt}")
# Out:
# Hipotenüs c = 13.0
# Hipotenüs (alternatif) c = 13.0

# %% [markdown]
# **Ders ve not:**

# %%
ders_ismi = 'Math'
ders_notu = 45
print(ders_ismi, ders_notu)
# Out:
# Math 45

# %% [markdown]
# **Küp kök:**

# %%
print(pow(8, 1/3))
# Out:
# 2.0

# %% [markdown]
# **Dairenin alanı:**

# %%
pi = 3.14
r = 7
Alan = pi * r ** 2
print(Alan)
# Out:
# 153.86

# %% [markdown]
# ## Kaynak
# - Tam emoji listesi: https://unicode.org/emoji/charts/full-emoji-list.html
